# %%
import os
from bs4 import BeautifulSoup
from playwright.async_api import async_playwright, TimeoutError as PlaywrightTimeout 
import time

# %%
SEASONS = list(range(2016, 2024))
SEASONS
# Out:
# [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]

# %%
DATA = "data2"
STANDINGS = os.path.join(DATA, "standings")
SCORES = os.path.join(DATA, "scores")

# %%
async  def get_html(url, selector, sleep=5, retries=3):
    html = None
    
    for i in range(1, retries + 1):
        #pauses the scrapping, so we don't get banned from the website
        time.sleep(sleep*1)
        
        #actual scrapping
        try:
            async with async_playwright() as p:
                browser = await p.chromium.launch()
                page = await browser.new_page()
                await page.goto(url)
                print(await page.title())
                html = await page.inner_html(selector)
        except PlaywrightTimeout:
            print("Timed out on {url}")
            continue
        else:
            break
    return html

# %%
season = 2023
url = f"https://www.basketball-reference.com/leagues/NBA_{season}_games.html"

# %%
url
# Out:
# 'https://www.basketball-reference.com/leagues/NBA_2023_games.html'

# %%
html = await get_html(url, "#content .filter")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 html = await get_html(url, "#content .filter")
#
# Cell In[37], line 10, in get_html(url, selector, sleep, retries)
#       8 #actual scrapping
#       9 try:
# ---> 10     async with async_playwright() as p:
#      11         browser = await p.chromium.launch()
#      12         page = await browser.new_page()
#
# File ~\OneDrive\Documents\Senior Design\Runtime@Github\venv\Lib\site-packages\playwright\async_api\_context_manager.py:47, in PlaywrightContextManager.__aenter__(self)
#      45 if not playwright_future.done():
#      46     playwright_future.cancel()
# ---> 47 playwright = AsyncPlaywright(next(iter(done)).result())
#      48 playwright.stop = self.__aexit__  # type: ignore
#      49 return playwright
#
# File ~\OneDrive\Documents\Senior Design\Runtime@Github\venv\Lib\site-packages\playwright\_impl\_transport.py:123, in PipeTransport.connect(self)
#     120         startupinfo.dwFlags |= subprocess.STARTF_USESHOWWINDOW
#     121         startupinfo.wShowWindow = subprocess.SW_HIDE
# --> 123     self._proc = await asyncio.create_subprocess_exec(
#     124         str(self._driver_executable),
#     125         "run-driver",
#     126         stdin=asyncio.subprocess.PIPE,
#     127         stdout=asyncio.subprocess.PIPE,
#     128         stderr=_get_stderr_fileno(),
#     129         limit=32768,
#     130         env=env,
#     131         startupinfo=startupinfo,
#     132     )
#     133 except Exception as exc:
#     134     self.on_error_future.set_exception(exc)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     221 loop = events.get_running_loop()
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:1742, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1740     debug_log = f'execute program {program!r}'
#    1741     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1742 transport = await self._make_subprocess_transport(
#    1743     protocol, popen_args, False, stdin, stdout, stderr,
#    1744     bufsize, **kwargs)
#    1745 if self._debug and debug_log is not None:
#    1746     logger.info('%s: %r', debug_log, transport)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:523, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     519 async def _make_subprocess_transport(self, protocol, args, shell,
#     520                                      stdin, stdout, stderr, bufsize,
#     521                                      extra=None, **kwargs):
#     522     """Create subprocess transport."""
# --> 523     raise NotImplementedError
#
# NotImplementedError:
