# %% [markdown]
# # Investigating Support Vector Classifiers

# %%
import pandas as pd
import numpy as np
from sklearn import metrics

# %%
path_to_data = "../../data/processed/processed_team_dataset.csv"

df = pd.read_csv(path_to_data, index_col=0)
df
# Out:
#              date  season team team_opp  team_elo_before  team_opp_elo_before
# 0      2015-10-29    2016  NYK      ATL      1356.009483          1541.442237  \
# 1      2015-10-29    2016  ATL      NYK      1541.442237          1356.009483
# 2      2015-10-29    2016  LAC      DAL      1652.435518          1559.753058
# 3      2015-10-29    2016  IND      MEM      1499.317744          1557.619147
# 4      2015-10-29    2016  MEM      IND      1557.619147          1499.317744
# ...           ...     ...  ...      ...              ...                  ...
# 21751  2024-02-15    2024  MIL      MEM      1539.547927          1410.179450
# 21752  2024-02-15    2024  MEM      MIL      1410.179450          1539.547927
# 21753  2024-02-15    2024  MIN      POR      1676.024592          1333.586609
# 21754  2024-02-15    2024  POR      MIN      1333.586609          1676.024592
# 21755  2024-02-15    2024  UTA      GSW      1487.046155          1578.339590
#
#        team_expected_win_probability  team_point_diff_proj  home  home_opp
# 0                           0.379472             -3.051170     1         0  \
# 1                           0.620528              3.051170     0         1
# 2                           0.751974              6.881516     1         0
# 3                           0.559723              1.489236     1         0
# 4                           0.440277             -1.489236     0         1
# ...                              ...                   ...   ...       ...
# 21751                       0.542164              1.048874     0         1
# 21752                       0.457836             -1.048874     1         0
# 21753                       0.801482              8.658499     0         1
# 21754                       0.198518             -8.658499     1         0
# 21755                       0.512527              0.310949     1         0
#
#        ...  orb%_max_allowed_last_10_opp  drb%_max_allowed_last_10_opp
# 0      ...                         18.50                         41.20  \
# 1      ...                         29.60                         20.50
# 2      ...                         19.30                         38.50
# 3      ...                         21.50                         34.50
# 4      ...                         22.30                         42.50
# ...    ...                           ...                           ...
# 21751  ...                         21.53                         35.17
# 21752  ...                         24.05                         40.78
# 21753  ...                         23.31                         33.23
# 21754  ...                         18.39                         38.21
# 21755  ...                         15.09                         35.02
#
#        trb%_max_allowed_last_10_opp  ast%_max_allowed_last_10_opp
# 0                             24.80                         35.60  \
# 1                             20.30                         34.90
# 2                             28.10                         32.20
# 3                             23.50                         30.60
# 4                             24.80                         30.20
# ...                             ...                           ...
# 21751                         26.01                         46.02
# 21752                         23.44                         43.28
# 21753                         22.67                         39.22
# 21754                         23.52                         44.58
# 21755                         20.10                         37.73
#
#        stl%_max_allowed_last_10_opp  blk%_max_allowed_last_10_opp
# 0                              3.20                          4.70  \
# 1                              3.40                          6.80
# 2                              4.20                          4.40
# 3                              8.40                         12.20
# 4                              2.60                          4.80
# ...                             ...                           ...
# 21751                          5.42                          9.31
# 21752                          5.62                          7.04
# 21753                         13.52                          8.59
# 21754                          4.41                          9.39
# 21755                          5.49                          8.24
#
#        tov%_max_allowed_last_10_opp  usg%_max_allowed_last_10_opp
# 0                             33.30                         23.60  \
# 1                             50.00                         32.50
# 2                             66.70                         27.90
# 3                            100.00                         28.00
# 4                            100.00                         29.70
# ...                             ...                           ...
# 21751                         36.66                         30.13
# 21752                         37.04                         43.73
# 21753                         36.08                         38.80
# 21754                         45.89                         35.88
# 21755                         36.14                         33.65
#
#        ortg_max_allowed_last_10_opp  drtg_max_allowed_last_10_opp
# 0                             132.0                         104.0
# 1                             140.0                         137.0
# 2                             162.0                         114.0
# 3                             149.0                          89.0
# 4                             134.0                         105.0
# ...                             ...                           ...
# 21751                         176.2                         115.0
# 21752                         175.3                         122.7
# 21753                         180.1                         124.0
# 21754                         191.6                         129.7
# 21755                         181.7                         128.6
#
# [21756 rows x 263 columns]

# %%
# drop these columns (most of the are non_numeric or are not useful for machine learning)
drop_columns = ["date", "season", "team", "team_opp", "won"]

selected_columns = df.columns[~df.columns.isin(drop_columns)]

# Selected features
features_df = df[selected_columns]
features_df
# Out:
#        team_elo_before  team_opp_elo_before  team_expected_win_probability
# 0          1356.009483          1541.442237                       0.379472  \
# 1          1541.442237          1356.009483                       0.620528
# 2          1652.435518          1559.753058                       0.751974
# 3          1499.317744          1557.619147                       0.559723
# 4          1557.619147          1499.317744                       0.440277
# ...                ...                  ...                            ...
# 21751      1539.547927          1410.179450                       0.542164
# 21752      1410.179450          1539.547927                       0.457836
# 21753      1676.024592          1333.586609                       0.801482
# 21754      1333.586609          1676.024592                       0.198518
# 21755      1487.046155          1578.339590                       0.512527
#
#        team_point_diff_proj  home  home_opp  fg_last_10  fga_last_10
# 0                 -3.051170     1         0        42.0         93.0  \
# 1                  3.051170     0         1        37.0         82.0
# 2                  6.881516     1         0        42.0         80.0
# 3                  1.489236     1         0        32.0         86.0
# 4                 -1.489236     0         1        29.0         82.0
# ...                     ...   ...       ...         ...          ...
# 21751              1.048874     0         1        42.0         87.1
# 21752             -1.048874     1         0        37.4         85.4
# 21753              8.658499     0         1        42.0         83.8
# 21754             -8.658499     1         0        40.4         86.0
# 21755              0.310949     1         0        44.5         91.4
#
#        fg%_last_10  3p_last_10  ...  orb%_max_allowed_last_10_opp
# 0           0.4520         9.0  ...                         18.50  \
# 1           0.4510         8.0  ...                         29.60
# 2           0.5250         6.0  ...                         19.30
# 3           0.3720         9.0  ...                         21.50
# 4           0.3540         2.0  ...                         22.30
# ...            ...         ...  ...                           ...
# 21751       0.4819        15.0  ...                         21.53
# 21752       0.4387        14.3  ...                         24.05
# 21753       0.5023        13.9  ...                         23.31
# 21754       0.4683        10.4  ...                         18.39
# 21755       0.4864        13.1  ...                         15.09
#
#        drb%_max_allowed_last_10_opp  trb%_max_allowed_last_10_opp
# 0                             41.20                         24.80  \
# 1                             20.50                         20.30
# 2                             38.50                         28.10
# 3                             34.50                         23.50
# 4                             42.50                         24.80
# ...                             ...                           ...
# 21751                         35.17                         26.01
# 21752                         40.78                         23.44
# 21753                         33.23                         22.67
# 21754                         38.21                         23.52
# 21755                         35.02                         20.10
#
#        ast%_max_allowed_last_10_opp  stl%_max_allowed_last_10_opp
# 0                             35.60                          3.20  \
# 1                             34.90                          3.40
# 2                             32.20                          4.20
# 3                             30.60                          8.40
# 4                             30.20                          2.60
# ...                             ...                           ...
# 21751                         46.02                          5.42
# 21752                         43.28                          5.62
# 21753                         39.22                         13.52
# 21754                         44.58                          4.41
# 21755                         37.73                          5.49
#
#        blk%_max_allowed_last_10_opp  tov%_max_allowed_last_10_opp
# 0                              4.70                         33.30  \
# 1                              6.80                         50.00
# 2                              4.40                         66.70
# 3                             12.20                        100.00
# 4                              4.80                        100.00
# ...                             ...                           ...
# 21751                          9.31                         36.66
# 21752                          7.04                         37.04
# 21753                          8.59                         36.08
# 21754                          9.39                         45.89
# 21755                          8.24                         36.14
#
#        usg%_max_allowed_last_10_opp  ortg_max_allowed_last_10_opp
# 0                             23.60                         132.0  \
# 1                             32.50                         140.0
# 2                             27.90                         162.0
# 3                             28.00                         149.0
# 4                             29.70                         134.0
# ...                             ...                           ...
# 21751                         30.13                         176.2
# 21752                         43.73                         175.3
# 21753                         38.80                         180.1
# 21754                         35.88                         191.6
# 21755                         33.65                         181.7
#
#        drtg_max_allowed_last_10_opp
# 0                             104.0
# 1                             137.0
# 2                             114.0
# 3                              89.0
# 4                             105.0
# ...                             ...
# 21751                         115.0
# 21752                         122.7
# 21753                         124.0
# 21754                         129.7
# 21755                         128.6
#
# [21756 rows x 258 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaled_features_df = pd.DataFrame(scaler.fit_transform(features_df), columns=features_df.columns)
scaled_features_df
# Out:
#        team_elo_before  team_opp_elo_before  team_expected_win_probability
# 0             0.240976             0.517230                       0.374891  \
# 1             0.517230             0.240976                       0.625109
# 2             0.682585             0.544509                       0.761551
# 3             0.454473             0.541330                       0.561992
# 4             0.541330             0.454473                       0.438008
# ...                ...                  ...                            ...
# 21751         0.514407             0.321677                       0.543767
# 21752         0.321677             0.514407                       0.456233
# 21753         0.717727             0.207571                       0.812940
# 21754         0.207571             0.717727                       0.187060
# 21755         0.436191             0.572198                       0.513003
#
#        team_point_diff_proj  home  home_opp  fg_last_10  fga_last_10
# 0                  0.438248   1.0       0.0    0.548387     0.454545  \
# 1                  0.561752   0.0       1.0    0.387097     0.204545
# 2                  0.639273   1.0       0.0    0.548387     0.159091
# 3                  0.530140   1.0       0.0    0.225806     0.295455
# 4                  0.469860   0.0       1.0    0.129032     0.204545
# ...                     ...   ...       ...         ...          ...
# 21751              0.521228   0.0       1.0    0.548387     0.320455
# 21752              0.478772   1.0       0.0    0.400000     0.281818
# 21753              0.675237   0.0       1.0    0.548387     0.245455
# 21754              0.324763   1.0       0.0    0.496774     0.295455
# 21755              0.506293   1.0       0.0    0.629032     0.418182
#
#        fg%_last_10  3p_last_10  ...  orb%_max_allowed_last_10_opp
# 0         0.562044    0.391304  ...                      0.143007  \
# 1         0.558394    0.347826  ...                      0.259727
# 2         0.828467    0.260870  ...                      0.151420
# 3         0.270073    0.391304  ...                      0.174553
# 4         0.204380    0.086957  ...                      0.182965
# ...            ...         ...  ...                           ...
# 21751     0.671168    0.652174  ...                      0.174869
# 21752     0.513504    0.621739  ...                      0.201367
# 21753     0.745620    0.604348  ...                      0.193586
# 21754     0.621533    0.452174  ...                      0.141851
# 21755     0.687591    0.569565  ...                      0.107150
#
#        drb%_max_allowed_last_10_opp  trb%_max_allowed_last_10_opp
# 0                          0.264080                      0.135632  \
# 1                          0.005006                      0.083908
# 2                          0.230288                      0.173563
# 3                          0.180225                      0.120690
# 4                          0.280350                      0.135632
# ...                             ...                           ...
# 21751                      0.188611                      0.149540
# 21752                      0.258824                      0.120000
# 21753                      0.164330                      0.111149
# 21754                      0.226658                      0.120920
# 21755                      0.186733                      0.081609
#
#        ast%_max_allowed_last_10_opp  stl%_max_allowed_last_10_opp
# 0                          0.182741                      0.062500  \
# 1                          0.173858                      0.071429
# 2                          0.139594                      0.107143
# 3                          0.119289                      0.294643
# 4                          0.114213                      0.035714
# ...                             ...                           ...
# 21751                      0.314975                      0.161607
# 21752                      0.280203                      0.170536
# 21753                      0.228680                      0.523214
# 21754                      0.296701                      0.116518
# 21755                      0.209772                      0.164732
#
#        blk%_max_allowed_last_10_opp  tov%_max_allowed_last_10_opp
# 0                          0.105856                      0.218970  \
# 1                          0.153153                      0.414520
# 2                          0.099099                      0.610070
# 3                          0.274775                      1.000000
# 4                          0.108108                      1.000000
# ...                             ...                           ...
# 21751                      0.209685                      0.258314
# 21752                      0.158559                      0.262763
# 21753                      0.193468                      0.251522
# 21754                      0.211486                      0.366393
# 21755                      0.185586                      0.252225
#
#        usg%_max_allowed_last_10_opp  ortg_max_allowed_last_10_opp
# 0                          0.000000                      0.120419  \
# 1                          0.116492                      0.162304
# 2                          0.056283                      0.277487
# 3                          0.057592                      0.209424
# 4                          0.079843                      0.130890
# ...                             ...                           ...
# 21751                      0.085471                      0.351832
# 21752                      0.263482                      0.347120
# 21753                      0.198953                      0.372251
# 21754                      0.160733                      0.432461
# 21755                      0.131545                      0.380628
#
#        drtg_max_allowed_last_10_opp
# 0                          0.303571
# 1                          0.892857
# 2                          0.482143
# 3                          0.035714
# 4                          0.321429
# ...                             ...
# 21751                      0.500000
# 21752                      0.637500
# 21753                      0.660714
# 21754                      0.762500
# 21755                      0.742857
#
# [21756 rows x 258 columns]

# %%
# Label we want to predict
label = df["won"]
label
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 21751    False
# 21752     True
# 21753     True
# 21754    False
# 21755    False
# Name: won, Length: 21756, dtype: bool

# %%
from sklearn import svm

# A simple support vector classifier
simple_svm_model = svm.SVC(probability=True, verbose=True)

# %% [markdown]
# # K-fold Cross Validation on our SVC

# %%
# We want to evaluate our SVC by performing a k-fold cross validation
X = scaled_features_df
Y = label

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=20, shuffle=True, random_state=42)

# Performing k-fold cross-validation
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(simple_svm_model, X, Y, cv=kf, scoring="accuracy")

# Prining CV scores
print("CV scores:", cv_scores)

# Averaging CV scores
print("Average score:", cv_scores.mean())
# Out:
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]CV scores: [0.64154412 0.66176471 0.68841912 0.66360294 0.62775735 0.65441176
#  0.63051471 0.640625   0.640625   0.65716912 0.62224265 0.65992647
#  0.64430147 0.68566176 0.66084559 0.63970588 0.63661454 0.63201472
#  0.64305428 0.65317387]
# Average score: 0.6491987526381298
